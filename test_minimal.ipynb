# %%
# 测试关键的 magic commands
print("=== Magic Commands 测试 ===")
print("1. 当前目录:")
# !pwd

# %%
# 测试 %cd
# %cd /content

# %%
# 测试 git clone
# !rm -rf test_repo
# !git clone https://github.com/ctz168/stdpbrain.git test_repo

# %%
# 测试切换到克隆目录
# %cd test_repo

# %%
# 验证目录内容
# !ls -la requirements.txt

# %%
# 测试 pip install (模拟)
print("如果 pip install 能看到 requirements.txt，说明 %cd 工作正常")
# !cat requirements.txt | head -5

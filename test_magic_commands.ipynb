# %%
# 测试 1: 基本目录操作
print("=== 测试 %cd 和 %pwd ===")
# %pwd

# %%
# 测试 2: 切换目录
# %cd /content

# %%
# 测试 3: Git clone
# !git clone https://github.com/ctz168/stdpbrain.git

# %%
# 测试 4: 切换到克隆的目录
# %cd stdpbrain

# %%
# 测试 5: 检查文件是否存在
# !ls -la

# %%
# 测试 6: 环境变量
# %set_env TEST_VAR hello_colabcli

# %%
# 测试 7: 读取环境变量
# %env TEST_VAR

# %%
# 测试 8: 查看当前目录
# !pwd
